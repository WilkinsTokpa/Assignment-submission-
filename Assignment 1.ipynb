# %%
#ASSIGNMENT 1
#GIVE A SORT OF LIST IN DESCENDINGG ORDER

li=['cat', 'dog', 'goat', 'sheep', 'deer', 'frog']
print('THESE ARE THE LIST OF ANIMALS')
li.sort()
li.reverse()
print(li)
# Out:
# THESE ARE THE LIST OF ANIMALS
# ['sheep', 'goat', 'frog', 'dog', 'deer', 'cat']
