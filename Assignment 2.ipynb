# %%
#OTP GENERATION PROJECT 
#UNIVERSITY AUTHENTICATION VERIFICATION OTP GENERATION 

import random as r
import string 
length=6
otp=''

characters=string.ascii_letters + string.digits
print(characters)
for i in range(length):
  otp=otp+(r.choice(characters))
print('USE VERIFICATION CODE FOR UNIVERSITY VERIFICATION', otp)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789
# USE VERIFICATION CODE FOR UNIVERSITY VERIFICATION BKTR3v
