# %%
#REMOVE ALL THE OCCURENCES OS AN ELEMENT FROM A LIST 
#USING THE LOOPING METHOD 

li=['beans', 'pepper', 'onions', 'pepper', 'oil', 'pepper',  'punkins', 'pepper', 'cabbage',]

while li.count('pepper')>0:
  li.remove('pepper')
print(li)
# Out:
# ['beans', 'onions', 'oil', 'punkins', 'cabbage']
